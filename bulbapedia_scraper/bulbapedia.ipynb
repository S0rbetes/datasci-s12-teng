# %% [markdown]
# # Bulbapedia Wiki Scraping
# ## Teng, Lance Ricco L.

# %% [markdown]
# ### Import libraries

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Prepare variables

# %%
URL = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number"

# %% [markdown]
# ### Load the page

# %%
page = requests.get(URL)

# %%
print(page.content)
# Out:
# ="background: #e6e6ff; padding: 2px 10px;"> <a href="/wiki/List_of_Pok%C3%A9mon_by_evolution_family" title="List of Pok\xc3\xa9mon by evolution family">evolution family</a> (<a href="/wiki/List_of_Pok%C3%A9mon_by_evolution_family_in_Pok%C3%A9mon_GO" title="List of Pok\xc3\xa9mon by evolution family in Pok\xc3\xa9mon GO">GO</a>) \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_that_are_not_part_of_an_evolutionary_line" title="List of Pok\xc3\xa9mon that are not part of an evolutionary line">no evolution family</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_with_branched_evolutions" title="List of Pok\xc3\xa9mon with branched evolutions">branched</a> \xe2\x80\xa2 <a href="/wiki/List_of_cross-generational_evolution_families" title="List of cross-generational evolution families">cross-generation</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_that_evolve_at_or_above_a_certain_level" title="List of Pok\xc3\xa9mon that evolve at or above a certain level">levels</a>\n</td></tr>\n<tr>\n<td colspan="2" height="1">\n</td></tr>\n<tr style="font-size: 90%;">\n<th style="background: #ddf; padding: 2px 15px;"> by in-game stats\n</th>\n<td style="background: #e6e6ff; padding: 2px 10px;"> <a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(Generation_VIII-present)" title="List of Pok\xc3\xa9mon by base stats (Generation VIII-present)">base stats</a> (<a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(Generation_I)" title="List of Pok\xc3\xa9mon by base stats (Generation I)">Gen I</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(Generation_II-V)" title="List of Pok\xc3\xa9mon by base stats (Generation II-V)">Gen II-V</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(Generation_VI)" title="List of Pok\xc3\xa9mon by base stats (Generation VI)">Gen VI</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(Generation_VII)" title="List of Pok\xc3\xa9mon by base stats (Generation VII)">Gen VII</a> \xe2\x80\xa2 <a href="/wiki/List_of_fully_evolved_Pok%C3%A9mon_by_base_stats" title="List of fully evolved Pok\xc3\xa9mon by base stats">fully evolved</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_with_unique_base_stat_totals" title="List of Pok\xc3\xa9mon with unique base stat totals">unique base stat totals</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_base_stats_(GO)" title="List of Pok\xc3\xa9mon by base stats (GO)">GO</a>)<br /><a href="/wiki/List_of_Pok%C3%A9mon_by_performance_stats" title="List of Pok\xc3\xa9mon by performance stats">performance stats</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_catch_rate" title="List of Pok\xc3\xa9mon by catch rate">catch rate</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield" title="List of Pok\xc3\xa9mon by effort value yield">EVs given in battle</a> (<a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield_(Generation_III)" title="List of Pok\xc3\xa9mon by effort value yield (Generation III)">Gen III</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield_(Generation_IV)" title="List of Pok\xc3\xa9mon by effort value yield (Generation IV)">Gen IV</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield_(Generation_V-VI)" title="List of Pok\xc3\xa9mon by effort value yield (Generation V-VI)">Gen V-VI</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield_(Generation_VII)" title="List of Pok\xc3\xa9mon by effort value yield (Generation VII)">Gen VII</a>) \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_gender_ratio" title="List of Pok\xc3\xa9mon by gender ratio">gender ratio</a><br /><a href="/wiki/List_of_Pok%C3%A9mon_by_base_Egg_cycles" title="List of Pok\xc3\xa9mon by base Egg cycles">steps to hatch</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_availability" title="List of Pok\xc3\xa9mon by availability">availability</a> \xe2\x80\xa2 <a href="/wiki/List_of_Pok%C3%A9mon_by_wild_held_item" title="List of Pok\xc3\xa9mon by wild held ...

# %% [markdown]
# ### Parse HTML data

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# ### Find all tables that contain Pokemon details

# %%
# Get main content <div>
poke_content = soup.find(id='mw-content-text')

# Get all table elements
poke_tables = poke_content.find_all('table')

# %% [markdown]
# ### Prepare variables

# %%
# Generation II to VIII is from index 2 to 8
gen_table_start, gen_table_end = 2, 8

# First Pokemon beings at index 3, Pokemon appear every other row.
info_start = 3

# Base url to Bulbapedia website
base_url = 'https://bulbapedia.bulbagarden.net'

# %% [markdown]
# ### Extract to array

# %%
all_gen_json = {}

for (index, gen_list) in enumerate(poke_tables[gen_table_start:gen_table_end+1], start=gen_table_start):
    gen_json = []

    for i in range(info_start, len(gen_list.contents), 2):
        poke_info = gen_list.contents[i]
        kdex = poke_info.contents[1].text.strip()
        ndex = poke_info.contents[3].text.strip()
        name = poke_info.contents[7].text.strip()
        url = base_url + poke_info.contents[7].contents[1].get('href')
        types = []
        types.append(poke_info.contents[9].text.strip())
        if len(poke_info.contents) > 10:
            types.append(poke_info.contents[11].text.strip())
        gen_json.append({
            "kdex": kdex,
            "ndex": ndex,
            "name": name,
            "types": types,
            "url": url
        })
    
    all_gen_json["gen" + str(index)] = gen_json

all_gen_json
# Out:
# 'Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Kommo-o_(Pok%C3%A9mon)'},
#   {'kdex': '#285',
#    'ndex': '#785',
#    'name': 'Tapu Koko',
#    'types': ['Electric', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Tapu_Koko_(Pok%C3%A9mon)'},
#   {'kdex': '#286',
#    'ndex': '#786',
#    'name': 'Tapu Lele',
#    'types': ['Psychic', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Tapu_Lele_(Pok%C3%A9mon)'},
#   {'kdex': '#287',
#    'ndex': '#787',
#    'name': 'Tapu Bulu',
#    'types': ['Grass', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Tapu_Bulu_(Pok%C3%A9mon)'},
#   {'kdex': '#288',
#    'ndex': '#788',
#    'name': 'Tapu Fini',
#    'types': ['Water', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Tapu_Fini_(Pok%C3%A9mon)'},
#   {'kdex': '#289',
#    'ndex': '#789',
#    'name': 'Cosmog',
#    'types': ['Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cosmog_(Pok%C3%A9mon)'},
#   {'kdex': '#290',
#    'ndex': '#790',
#    'name': 'Cosmoem',
#    'types': ['Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cosmoem_(Pok%C3%A9mon)'},
#   {'kdex': '#291',
#    'ndex': '#791',
#    'name': 'Solgaleo',
#    'types': ['Psychic', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Solgaleo_(Pok%C3%A9mon)'},
#   {'kdex': '#292',
#    'ndex': '#792',
#    'name': 'Lunala',
#    'types': ['Psychic', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Lunala_(Pok%C3%A9mon)'},
#   {'kdex': '#293',
#    'ndex': '#793',
#    'name': 'Nihilego',
#    'types': ['Rock', 'Poison'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Nihilego_(Pok%C3%A9mon)'},
#   {'kdex': '#294',
#    'ndex': '#794',
#    'name': 'Buzzwole',
#    'types': ['Bug', 'Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Buzzwole_(Pok%C3%A9mon)'},
#   {'kdex': '#295',
#    'ndex': '#795',
#    'name': 'Pheromosa',
#    'types': ['Bug', 'Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Pheromosa_(Pok%C3%A9mon)'},
#   {'kdex': '#296',
#    'ndex': '#796',
#    'name': 'Xurkitree',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Xurkitree_(Pok%C3%A9mon)'},
#   {'kdex': '#297',
#    'ndex': '#797',
#    'name': 'Celesteela',
#    'types': ['Steel', 'Flying'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Celesteela_(Pok%C3%A9mon)'},
#   {'kdex': '#298',
#    'ndex': '#798',
#    'name': 'Kartana',
#    'types': ['Grass', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Kartana_(Pok%C3%A9mon)'},
#   {'kdex': '#299',
#    'ndex': '#799',
#    'name': 'Guzzlord',
#    'types': ['Dark', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Guzzlord_(Pok%C3%A9mon)'},
#   {'kdex': '#300',
#    'ndex': '#800',
#    'name': 'Necrozma',
#    'types': ['Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Necrozma_(Pok%C3%A9mon)'},
#   {'kdex': '#301',
#    'ndex': '#801',
#    'name': 'Magearna',
#    'types': ['Steel', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Magearna_(Pok%C3%A9mon)'},
#   {'kdex': '#302',
#    'ndex': '#802',
#    'name': 'Marshadow',
#    'types': ['Fighting', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Marshadow_(Pok%C3%A9mon)'},
#   {'kdex': '#261',
#    'ndex': '#803',
#    'name': 'Poipole',
#    'types': ['Poison'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Poipole_(Pok%C3%A9mon)'},
#   {'kdex': '#262',
#    'ndex': '#804',
#    'name': 'Naganadel',
#    'types': ['Poison', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Naganadel_(Pok%C3%A9mon)'},
#   {'kdex': '#392',
#    'ndex': '#805',
#    'name': 'Stakataka',
#    'types': ['Rock', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Stakataka_(Pok%C3%A9mon)'},
#   {'kdex': '#393',
#    'ndex': '#806',
#    'name': 'Blacephalon',
#    'types': ['Fire', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Blacephalon_(Pok%C3%A9mon)'},
#   {'kdex': '#403',
#    'ndex': '#807',
#    'name': 'Zeraora',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zeraora_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#808',
#    'name': 'Meltan',
#    'types': ['Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Meltan_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#809',
#    'name': 'Melmetal',
#    'types': ['Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Melmetal_(Pok%C3%A9mon)'}],
#  'gen8': [{'kdex': '#001',
#    'ndex': '#810',
#    'name': 'Grookey',
#    'types': ['Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Grookey_(Pok%C3%A9mon)'},
#   {'kdex': '#002',
#    'ndex': '#811',
#    'name': 'Thwackey',
#    'types': ['Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Thwackey_(Pok%C3%A9mon)'},
#   {'kdex': '#003',
#    'ndex': '#812',
#    'name': 'Rillaboom',
#    'types': ['Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Rillaboom_(Pok%C3%A9mon)'},
#   {'kdex': '#004',
#    'ndex': '#813',
#    'name': 'Scorbunny',
#    'types': ['Fire'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Scorbunny_(Pok%C3%A9mon)'},
#   {'kdex': '#005',
#    'ndex': '#814',
#    'name': 'Raboot',
#    'types': ['Fire'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Raboot_(Pok%C3%A9mon)'},
#   {'kdex': '#006',
#    'ndex': '#815',
#    'name': 'Cinderace',
#    'types': ['Fire'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cinderace_(Pok%C3%A9mon)'},
#   {'kdex': '#007',
#    'ndex': '#816',
#    'name': 'Sobble',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Sobble_(Pok%C3%A9mon)'},
#   {'kdex': '#008',
#    'ndex': '#817',
#    'name': 'Drizzile',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Drizzile_(Pok%C3%A9mon)'},
#   {'kdex': '#009',
#    'ndex': '#818',
#    'name': 'Inteleon',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Inteleon_(Pok%C3%A9mon)'},
#   {'kdex': '#024',
#    'ndex': '#819',
#    'name': 'Skwovet',
#    'types': ['Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Skwovet_(Pok%C3%A9mon)'},
#   {'kdex': '#025',
#    'ndex': '#820',
#    'name': 'Greedent',
#    'types': ['Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Greedent_(Pok%C3%A9mon)'},
#   {'kdex': '#021',
#    'ndex': '#821',
#    'name': 'Rookidee',
#    'types': ['Flying'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Rookidee_(Pok%C3%A9mon)'},
#   {'kdex': '#022',
#    'ndex': '#822',
#    'name': 'Corvisquire',
#    'types': ['Flying'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Corvisquire_(Pok%C3%A9mon)'},
#   {'kdex': '#023',
#    'ndex': '#823',
#    'name': 'Corviknight',
#    'types': ['Flying', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Corviknight_(Pok%C3%A9mon)'},
#   {'kdex': '#010',
#    'ndex': '#824',
#    'name': 'Blipbug',
#    'types': ['Bug'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Blipbug_(Pok%C3%A9mon)'},
#   {'kdex': '#011',
#    'ndex': '#825',
#    'name': 'Dottler',
#    'types': ['Bug', 'Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dottler_(Pok%C3%A9mon)'},
#   {'kdex': '#012',
#    'ndex': '#826',
#    'name': 'Orbeetle',
#    'types': ['Bug', 'Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Orbeetle_(Pok%C3%A9mon)'},
#   {'kdex': '#029',
#    'ndex': '#827',
#    'name': 'Nickit',
#    'types': ['Dark'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Nickit_(Pok%C3%A9mon)'},
#   {'kdex': '#030',
#    'ndex': '#828',
#    'name': 'Thievul',
#    'types': ['Dark'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Thievul_(Pok%C3%A9mon)'},
#   {'kdex': '#126',
#    'ndex': '#829',
#    'name': 'Gossifleur',
#    'types': ['Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Gossifleur_(Pok%C3%A9mon)'},
#   {'kdex': '#127',
#    'ndex': '#830',
#    'name': 'Eldegoss',
#    'types': ['Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Eldegoss_(Pok%C3%A9mon)'},
#   {'kdex': '#034',
#    'ndex': '#831',
#    'name': 'Wooloo',
#    'types': ['Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Wooloo_(Pok%C3%A9mon)'},
#   {'kdex': '#035',
#    'ndex': '#832',
#    'name': 'Dubwool',
#    'types': ['Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dubwool_(Pok%C3%A9mon)'},
#   {'kdex': '#042',
#    'ndex': '#833',
#    'name': 'Chewtle',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Chewtle_(Pok%C3%A9mon)'},
#   {'kdex': '#043',
#    'ndex': '#834',
#    'name': 'Drednaw',
#    'types': ['Water', 'Rock'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Drednaw_(Pok%C3%A9mon)'},
#   {'kdex': '#046',
#    'ndex': '#835',
#    'name': 'Yamper',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Yamper_(Pok%C3%A9mon)'},
#   {'kdex': '#047',
#    'ndex': '#836',
#    'name': 'Boltund',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Boltund_(Pok%C3%A9mon)'},
#   {'kdex': '#161',
#    'ndex': '#837',
#    'name': 'Rolycoly',
#    'types': ['Rock'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Rolycoly_(Pok%C3%A9mon)'},
#   {'kdex': '#162',
#    'ndex': '#838',
#    'name': 'Carkol',
#    'types': ['Rock', 'Fire'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Carkol_(Pok%C3%A9mon)'},
#   {'kdex': '#163',
#    'ndex': '#839',
#    'name': 'Coalossal',
#    'types': ['Rock', 'Fire'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Coalossal_(Pok%C3%A9mon)'},
#   {'kdex': '#205',
#    'ndex': '#840',
#    'name': 'Applin',
#    'types': ['Grass', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Applin_(Pok%C3%A9mon)'},
#   {'kdex': '#206',
#    'ndex': '#841',
#    'name': 'Flapple',
#    'types': ['Grass', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Flapple_(Pok%C3%A9mon)'},
#   {'kdex': '#207',
#    'ndex': '#842',
#    'name': 'Appletun',
#    'types': ['Grass', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Appletun_(Pok%C3%A9mon)'},
#   {'kdex': '#312',
#    'ndex': '#843',
#    'name': 'Silicobra',
#    'types': ['Ground'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Silicobra_(Pok%C3%A9mon)'},
#   {'kdex': '#313',
#    'ndex': '#844',
#    'name': 'Sandaconda',
#    'types': ['Ground'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Sandaconda_(Pok%C3%A9mon)'},
#   {'kdex': '#309',
#    'ndex': '#845',
#    'name': 'Cramorant',
#    'types': ['Flying', 'Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cramorant_(Pok%C3%A9mon)'},
#   {'kdex': '#180',
#    'ndex': '#846',
#    'name': 'Arrokuda',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Arrokuda_(Pok%C3%A9mon)'},
#   {'kdex': '#181',
#    'ndex': '#847',
#    'name': 'Barraskewda',
#    'types': ['Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Barraskewda_(Pok%C3%A9mon)'},
#   {'kdex': '#310',
#    'ndex': '#848',
#    'name': 'Toxel',
#    'types': ['Electric', 'Poison'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Toxel_(Pok%C3%A9mon)'},
#   {'kdex': '#311',
#    'ndex': '#849',
#    'name': 'Toxtricity',
#    'types': ['Electric', 'Poison'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Toxtricity_(Pok%C3%A9mon)'},
#   {'kdex': '#159',
#    'ndex': '#850',
#    'name': 'Sizzlipede',
#    'types': ['Fire', 'Bug'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Sizzlipede_(Pok%C3%A9mon)'},
#   {'kdex': '#160',
#    'ndex': '#851',
#    'name': 'Centiskorch',
#    'types': ['Fire', 'Bug'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Centiskorch_(Pok%C3%A9mon)'},
#   {'kdex': '#351',
#    'ndex': '#852',
#    'name': 'Clobbopus',
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Clobbopus_(Pok%C3%A9mon)'},
#   {'kdex': '#352',
#    'ndex': '#853',
#    'name': 'Grapploct',
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Grapploct_(Pok%C3%A9mon)'},
#   {'kdex': '#335',
#    'ndex': '#854',
#    'name': 'Sinistea',
#    'types': ['Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Sinistea_(Pok%C3%A9mon)'},
#   {'kdex': '#336',
#    'ndex': '#855',
#    'name': 'Polteageist',
#    'types': ['Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Polteageist_(Pok%C3%A9mon)'},
#   {'kdex': '#241',
#    'ndex': '#856',
#    'name': 'Hatenna',
#    'types': ['Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Hatenna_(Pok%C3%A9mon)'},
#   {'kdex': '#242',
#    'ndex': '#857',
#    'name': 'Hattrem',
#    'types': ['Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Hattrem_(Pok%C3%A9mon)'},
#   {'kdex': '#243',
#    'ndex': '#858',
#    'name': 'Hatterene',
#    'types': ['Psychic', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Hatterene_(Pok%C3%A9mon)'},
#   {'kdex': '#238',
#    'ndex': '#859',
#    'name': 'Impidimp',
#    'types': ['Dark', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Impidimp_(Pok%C3%A9mon)'},
#   {'kdex': '#239',
#    'ndex': '#860',
#    'name': 'Morgrem',
#    'types': ['Dark', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Morgrem_(Pok%C3%A9mon)'},
#   {'kdex': '#240',
#    'ndex': '#861',
#    'name': 'Grimmsnarl',
#    'types': ['Dark', 'Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Grimmsnarl_(Pok%C3%A9mon)'},
#   {'kdex': '#033',
#    'ndex': '#862',
#    'name': 'Obstagoon',
#    'types': ['Dark', 'Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Obstagoon_(Pok%C3%A9mon)'},
#   {'kdex': '#183',
#    'ndex': '#863',
#    'name': 'Perrserker',
#    'types': ['Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Perrserker_(Pok%C3%A9mon)'},
#   {'kdex': '#237',
#    'ndex': '#864',
#    'name': 'Cursola',
#    'types': ['Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cursola_(Pok%C3%A9mon)'},
#   {'kdex': '#219',
#    'ndex': '#865',
#    'name': "Sirfetch'd",
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Sirfetch%27d_(Pok%C3%A9mon)'},
#   {'kdex': '#366',
#    'ndex': '#866',
#    'name': 'Mr. Rime',
#    'types': ['Ice', 'Psychic'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Mr._Rime_(Pok%C3%A9mon)'},
#   {'kdex': '#328',
#    'ndex': '#867',
#    'name': 'Runerigus',
#    'types': ['Ground', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Runerigus_(Pok%C3%A9mon)'},
#   {'kdex': '#185',
#    'ndex': '#868',
#    'name': 'Milcery',
#    'types': ['Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Milcery_(Pok%C3%A9mon)'},
#   {'kdex': '#186',
#    'ndex': '#869',
#    'name': 'Alcremie',
#    'types': ['Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Alcremie_(Pok%C3%A9mon)'},
#   {'kdex': '#345',
#    'ndex': '#870',
#    'name': 'Falinks',
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Falinks_(Pok%C3%A9mon)'},
#   {'kdex': '#353',
#    'ndex': '#871',
#    'name': 'Pincurchin',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Pincurchin_(Pok%C3%A9mon)'},
#   {'kdex': '#349',
#    'ndex': '#872',
#    'name': 'Snom',
#    'types': ['Ice', 'Bug'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Snom_(Pok%C3%A9mon)'},
#   {'kdex': '#350',
#    'ndex': '#873',
#    'name': 'Frosmoth',
#    'types': ['Ice', 'Bug'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Frosmoth_(Pok%C3%A9mon)'},
#   {'kdex': '#369',
#    'ndex': '#874',
#    'name': 'Stonjourner',
#    'types': ['Rock'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Stonjourner_(Pok%C3%A9mon)'},
#   {'kdex': '#370',
#    'ndex': '#875',
#    'name': 'Eiscue',
#    'types': ['Ice'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Eiscue_(Pok%C3%A9mon)'},
#   {'kdex': '#337',
#    'ndex': '#876',
#    'name': 'Indeedee',
#    'types': ['Psychic', 'Normal'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Indeedee_(Pok%C3%A9mon)'},
#   {'kdex': '#344',
#    'ndex': '#877',
#    'name': 'Morpeko',
#    'types': ['Electric', 'Dark'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Morpeko_(Pok%C3%A9mon)'},
#   {'kdex': '#302',
#    'ndex': '#878',
#    'name': 'Cufant',
#    'types': ['Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Cufant_(Pok%C3%A9mon)'},
#   {'kdex': '#303',
#    'ndex': '#879',
#    'name': 'Copperajah',
#    'types': ['Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Copperajah_(Pok%C3%A9mon)'},
#   {'kdex': '#374',
#    'ndex': '#880',
#    'name': 'Dracozolt',
#    'types': ['Electric', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dracozolt_(Pok%C3%A9mon)'},
#   {'kdex': '#375',
#    'ndex': '#881',
#    'name': 'Arctozolt',
#    'types': ['Electric', 'Ice'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Arctozolt_(Pok%C3%A9mon)'},
#   {'kdex': '#376',
#    'ndex': '#882',
#    'name': 'Dracovish',
#    'types': ['Water', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dracovish_(Pok%C3%A9mon)'},
#   {'kdex': '#377',
#    'ndex': '#883',
#    'name': 'Arctovish',
#    'types': ['Water', 'Ice'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Arctovish_(Pok%C3%A9mon)'},
#   {'kdex': '#371',
#    'ndex': '#884',
#    'name': 'Duraludon',
#    'types': ['Steel', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Duraludon_(Pok%C3%A9mon)'},
#   {'kdex': '#395',
#    'ndex': '#885',
#    'name': 'Dreepy',
#    'types': ['Dragon', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dreepy_(Pok%C3%A9mon)'},
#   {'kdex': '#396',
#    'ndex': '#886',
#    'name': 'Drakloak',
#    'types': ['Dragon', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Drakloak_(Pok%C3%A9mon)'},
#   {'kdex': '#397',
#    'ndex': '#887',
#    'name': 'Dragapult',
#    'types': ['Dragon', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Dragapult_(Pok%C3%A9mon)'},
#   {'kdex': '#398',
#    'ndex': '#888',
#    'name': 'Zacian',
#    'types': ['Fairy'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zacian_(Pok%C3%A9mon)'},
#   {'kdex': '#398',
#    'ndex': '#888',
#    'name': 'Zacian',
#    'types': ['Fairy', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zacian_(Pok%C3%A9mon)'},
#   {'kdex': '#399',
#    'ndex': '#889',
#    'name': 'Zamazenta',
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)'},
#   {'kdex': '#399',
#    'ndex': '#889',
#    'name': 'Zamazenta',
#    'types': ['Fighting', 'Steel'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)'},
#   {'kdex': '#400',
#    'ndex': '#890',
#    'name': 'Eternatus',
#    'types': ['Poison', 'Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Eternatus_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#891',
#    'name': 'Kubfu',
#    'types': ['Fighting'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Kubfu_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#892',
#    'name': 'Urshifu',
#    'types': ['Fighting', 'Dark'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#892',
#    'name': 'Urshifu',
#    'types': ['Fighting', 'Water'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#893',
#    'name': 'Zarude',
#    'types': ['Dark', 'Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Zarude_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#894',
#    'name': 'Regieleki',
#    'types': ['Electric'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Regieleki_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#895',
#    'name': 'Regidrago',
#    'types': ['Dragon'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Regidrago_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#896',
#    'name': 'Glastrier',
#    'types': ['Ice'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Glastrier_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#897',
#    'name': 'Spectrier',
#    'types': ['Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Spectrier_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#898',
#    'name': 'Calyrex',
#    'types': ['Psychic', 'Grass'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#898',
#    'name': 'Calyrex',
#    'types': ['Psychic', 'Ice'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'},
#   {'kdex': '#---',
#    'ndex': '#898',
#    'name': 'Calyrex',
#    'types': ['Psychic', 'Ghost'],
#    'url': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'}]}

# %% [markdown]
# ### Save to JSON file

# %%
import json
import os

filepath = ''

# %%
with open(os.path.join(filepath, 'pokedex.json'), 'w', encoding='utf-8') as f:
    json.dump(all_gen_json, f, ensure_ascii=False, indent=4)
